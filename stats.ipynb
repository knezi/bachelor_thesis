# %%
from load_data import Data

# %%
data = Data('data/data.json', 'data/geneea_data_extracted.json')

# %%
data.generate_sample('useful')
# Out:
# 45187

# %%
from load_data import SampleTypeEnum
fs = data.get_feature_dict(SampleTypeEnum.TRAIN)

# %%
import matplotlib.pyplot as plt

# %%
pos = data.data[data.data['useful'] > 2].sample(frac=1).copy()
pos['color']='blue'
neg = data.data[data.data['useful'] == 0].sample(frac=1).copy()
neg['color']='red'

# %%
import pandas as pd

# %%
d=pd.concat([pos, neg]).reset_index()
d2=pd.concat([neg, pos]).reset_index()

# %%
plt.scatter(d['incorrect_words'], d['useful'], c=d['color'])

# %%
plt.scatter(d2['incorrect_words'], d2['useful'], c=d2['color'])

# %%
plt.scatter(d['sentiment'], d['useful'], c=d['color'])

# %%
plt.scatter(d2['sentiment'], d2['useful'], c=d2['color'])

# %%
len(pos)
# Out:
# 19631

# %%
len(neg)
# Out:
# 44923

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d2['incorrect_words'], d2['sentiment'], c=d2['color'])

# %%
plt.scatter(d['cool'], d['incorrect_words'], c=d['color'])

# %%
plt.scatter(d2['cool'], d2['incorrect_words'], c=d2['color'])

# %%
# useful more incorrect words

# %%
plt.scatter(d['stars'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d2['stars'], d2['sentiment'], c=d2['color'])

# %%
plt.scatter(d['words'], d['incorrect_words'], c=d['color'])

# %%
plt.scatter(d2['words'], d2['incorrect_words'], c=d2['color'])

# %%
plt.scatter(d['words'], d['stars'], c=d['color'])

# %%
plt.scatter(d['words'], d['stars'], c=d2['color'])

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
plt.scatter(d['incorrect_words'], d['sentiment'], c=d['color'])

# %%
d
# Out:
#        level_0  index                                        business_id  \
# 0       194242      0  {'business_id': 'n_-CwlqV8fzEIUPky8Ibtw', 'nam...
# 1        58045      0  {'business_id': 'aD-YA02i2xAqLBDon1tzIQ', 'nam...
# 2       165308      0  {'business_id': 'drIFrAyZnyismS1ArZlmAg', 'nam...
# 3       184265      0  {'business_id': 'OETh78qcgDltvHULowwhJg', 'nam...
# 4       191578      0  {'business_id': 'hYX0z2C6Th5XmcrKOP31fQ', 'nam...
# 5       115090      0  {'business_id': '-9YyInW1wapzdNZrhQJ9dg', 'nam...
# 6       125921      0  {'business_id': 'f2BFIjiKorIh9SARv8s_ug', 'nam...
# 7       105563      0  {'business_id': 'vAh6WNioOEw7G9tGhd_JQw', 'nam...
# 8        16503      0  {'business_id': 'VhEWjWUrcHFFNAyZN-TzyQ', 'nam...
# 9       114042      0  {'business_id': 'TT2bNjvnVNFOanDNYnAffQ', 'nam...
# 10      102415      0  {'business_id': 'MAugaG_RkNvT0ojmkTvexw', 'nam...
# 11      167250      0  {'business_id': 'Ffhe2cmRyloz3CCdRGvHtA', 'nam...
# ...
